# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras import Input

dataset = tf.keras.preprocessing.image_dataset_from_directory(
    r"C:\Users\rogbg\Downloads\homer_bart",  
    image_size=(64, 64),
    label_mode="binary"
)

train_data = dataset.take(8)
test_data = dataset.skip(8)
train_data = train_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_data = test_data.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# Define preprocessing layer
preprocess = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1./255) 
])

# Define the model
model = tf.keras.Sequential([
    Input(shape=(64, 64, 3)),
    Flatten(),
    preprocess,
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid') 
])

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),  # Optimizer
    loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),  # Loss function
    metrics=['accuracy']  # Metric
)

# Train the model
model.fit(
    train_data,
    epochs=20,  # Number of epochs
    verbose=1,
    validation_data=test_data
)

# Evaluate the model
test_loss, test_acc = model.evaluate(test_data)

print(f'Test Accuracy: {test_acc:.4f}')

if test_acc > 0.9:
    print("Assignment Passed")
else:
    print("Assignment Failed")
# Out:
# Found 269 files belonging to 2 classes.
# Epoch 1/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.4538 - loss: 2.5032 - val_accuracy: 0.4615 - val_loss: 2.5470
# Epoch 2/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5843 - loss: 1.3108 - val_accuracy: 0.5385 - val_loss: 0.7675
# Epoch 3/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6051 - loss: 0.7500 - val_accuracy: 0.4615 - val_loss: 0.7413
# Epoch 4/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6571 - loss: 0.6635 - val_accuracy: 0.8462 - val_loss: 0.3893
# Epoch 5/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6712 - loss: 0.5773 - val_accuracy: 0.8462 - val_loss: 0.3017
# Epoch 6/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8023 - loss: 0.4370 - val_accuracy: 0.8462 - val_loss: 0.3674
# Epoch 7/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8035 - loss: 0.4545 - val_accuracy: 0.8462 - val_loss: 0.4195
# Epoch 8/20
# ...
